# %%
import pandas as pd

# %%
demo= pd.read_csv('C:/Users/clair/Desktop/Flex 4/Python/World Indicators.csv')
demo.head()
# Out:
#        Country  Year  Births attended by skilled health staff (% of total)  \
# 0  Afghanistan  1960                                                NaN
# 1  Afghanistan  1961                                                NaN
# 2  Afghanistan  1962                                                NaN
# 3  Afghanistan  1963                                                NaN
# 4  Afghanistan  1964                                                NaN
#
#    Current health expenditure (% of GDP)  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Current health expenditure per capita (current US$)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
demo.shape
# Out:
# (11792, 16)

# %%
demo.columns
# Out:
# Index(['Country', 'Year',
#        'Births attended by skilled health staff (% of total)',
#        'Current health expenditure (% of GDP)',
#        'Current health expenditure per capita (current US$)',
#        'Female genital mutilation prevalence (%)', 'GDP (current US$)',
#        'Hospital beds (per 1,000 people)',
#        'Life expectancy at birth, female (years)',
#        'Life expectancy at birth, male (years)',
#        'Lifetime risk of maternal death (%)',
#        'Nurses and midwives (per 1,000 people)',
#        'Proportion of women subjected to physical and/or sexual violence in the last 12 months (% of women age 15-49)',
#        'Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)',
#        'Women who were first married by age 15 (% of women ages 20-24)',
#        'Fistula country'],
#       dtype='object')

# %%
demo.dtypes
# Out:
# Country                                                                                                           object
# Year                                                                                                               int64
# Births attended by skilled health staff (% of total)                                                             float64
# Current health expenditure (% of GDP)                                                                            float64
# Current health expenditure per capita (current US$)                                                              float64
# Female genital mutilation prevalence (%)                                                                         float64
# GDP (current US$)                                                                                                float64
# Hospital beds (per 1,000 people)                                                                                 float64
# ...

# %%
demo.describe()
# Out:
#                Year  Births attended by skilled health staff (% of total)  \
# count  11792.000000                                        2426.000000
# mean    1989.018911                                          88.403825
# std       16.690467                                          20.981483
# min     1960.000000                                           5.000000
# 25%     1975.000000                                          89.900000
# 50%     1989.000000                                          98.600000
# 75%     2004.000000                                          99.700000
# max     2017.000000                                         100.000000
#
#        Current health expenditure (% of GDP)  \
# count                            2976.000000
# mean                                6.275546
# std                                 2.851586
# min                                 0.838727
# 25%                                 4.360069
# 50%                                 5.786223
# ...

# %%
indi= pd.read_excel('C:/Users/clair/Desktop/Flex 4/Python/DESI.xlsx')
indi.head()
# Out:
#    Year       Indicator      Country Country Code  Weighted Score
# 0  2018  1 Connectivity      Denmark           DK         19.6205
# 1  2018  1 Connectivity       Sweden           SE         18.9963
# 2  2018  1 Connectivity      Finland           FI         16.5132
# 3  2018  1 Connectivity  Netherlands           NL         20.2830
# 4  2018  1 Connectivity   Luxembourg           LU         20.0132

# %%
indi.shape
# Out:
# (725, 5)

# %%
indi.columns
# Out:
# Index(['Year', 'Indicator', 'Country', 'Country Code', 'Weighted Score'], dtype='object')

# %%
indi.dtypes
# Out:
# Year                int64
# Indicator          object
# Country            object
# Country Code       object
# Weighted Score    float64
# dtype: object

# %%
indi.describe()
# Out:
#              Year  Weighted Score
# count   725.00000      725.000000
# mean   2016.00000        9.712147
# std       1.41519        3.880509
# min    2014.00000        2.871540
# 25%    2015.00000        6.776470
# 50%    2016.00000        8.828910
# 75%    2017.00000       12.349100
# max    2018.00000       20.283000

# %%
joined_data= pd.merge(demo,indi,on='Country',how='left')
joined_data
# Out:
#            Country  Year_x  \
# 0      Afghanistan    1960
# 1      Afghanistan    1961
# 2      Afghanistan    1962
# 3      Afghanistan    1963
# 4      Afghanistan    1964
# ...            ...     ...
# 49371     Zimbabwe    2013
# 49372     Zimbabwe    2014
# 49373     Zimbabwe    2015
# 49374     Zimbabwe    2016
# 49375     Zimbabwe    2017
#
#        Births attended by skilled health staff (% of total)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49371                                                NaN
# 49372                                               80.0
# 49373                                               78.1
# ...

# %%
joined_data.isnull().values.any()
# Out:
# True

# %%
new_joined_data=joined_data.fillna(joined_data.median())
new_joined_data
# Out:
#            Country  Year_x  \
# 0      Afghanistan    1960
# 1      Afghanistan    1961
# 2      Afghanistan    1962
# 3      Afghanistan    1963
# 4      Afghanistan    1964
# ...            ...     ...
# 49371     Zimbabwe    2013
# 49372     Zimbabwe    2014
# 49373     Zimbabwe    2015
# 49374     Zimbabwe    2016
# 49375     Zimbabwe    2017
#
#        Births attended by skilled health staff (% of total)  \
# 0                                                   99.6
# 1                                                   99.6
# 2                                                   99.6
# 3                                                   99.6
# 4                                                   99.6
# ...                                                  ...
# 49371                                               99.6
# 49372                                               80.0
# 49373                                               78.1
# ...
